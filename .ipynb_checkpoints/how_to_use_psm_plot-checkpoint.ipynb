# %% [markdown]
# # Examples of Using *psm_plot.py*
#
# I put together a bunch of functions a few years ago to make using the *matplotlib* library a little easier. Basically, *psm_plot.py* allows you to assemble details about a chart of series of charts into variables in your own code and with a single function call send these to *psm_plot.py* to be plotted in the way you want.
#
# Although I use this code a lot... it's not really that thoroughly tested, so you will likely run into issues, but hopefully this makes learning to use matplotlib a littler easier at first...
#
# <a id='setup'></a>
# ## Setting up a jupyter-lab notebook to use psm_plot.py
#
# The following is necessary to setup your jupyter-lab notebook. You can use the following code cell once and the rest of the notebook should work.

# %%
# %matplotlib inline

from math import *
import sympy as sympy
import sys
sys.path.append("/home/elemley/engr3703")
###NOTE: Your psm_plot.py will be in a different location...
from psm_plot import *

## You need to run this cell at least once before moving forward.

# %% [markdown]
# <a id='lineplot1'></a>
# ### Line Plot of One Function

# %%
# Note this is specified def f_string():
def f_string():
    fn_string = "a*x*exp(0.5*x)+1.2*x -5"
    return fn_string

def f(a, x):
    string = f_string()
    tmp = eval(string)
    return tmp

# LinePlot111
# If you have one list
x = np.arange(0, 10, .1)
a1 = 0.5
f1 = []

for num in x:
    f1.append(f(a1, num))

LinePlot111(x,f1,"x","f(x)","LinePlot111","LinePlot111.png")

# %% [markdown]
# <a id='scatterplot1'></a>
# ## Scatterplot of One Set of Data

# %%
# ScatterPlot111
# To make the same plot as before but with points/markers instead of a line
ScatterPlot111(x,f1,"x","f(x)","ScatterPlot111","ScatterPlot111.png")

# %% [markdown]
# <a id='lineplot2'></a>
# ## Line Plot with Two Functions

# %%
# TwoLineColorsPlot111
a2 = 0.8
f2 = []
for num in x:
    f2.append(f(a2, num))

# To make a plot with two lines with different colors
TwoLineColorsPlot111(x,f1,"f1",f2,"f2","x","f(x)","TwoLineColorsPlot111","TwoLineColorsPlot111.png")
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# <a id='lineplotmulti'></a>
# ## Plotting Multiple Functions as Line-plots
# Below are several examples with up to five functions. Note these don't necessarily have to be *functions* these will work with any $(x,y)$ data... these plots just join data with *lines*. So the function-like appearance here is dependent on having many points in the $(x,y)$ data set.

# %%
# ThreeLineColorsPlot111
a3 = 0.3
f3 = []
for num in x:
    f3.append(f(a3, num))
ThreeLineColorsPlot111(x,f1,"f1",f2,"f2",f3,"f3","x","f(x)","ThreeLineColorsPlot111","ThreeLineColorsPlot111.png")

# FourLineColorsPlot111
a4 = 0.2
f4 = []
for num in x:
    f4.append(f(a4, num))
FourLineColorsPlot111(x,f1,"f1",f2,"f2",f3,"f3",f4,"f4","x","f(x)","FourLineColorsPlot111","FourLineColorsPlot111.png")

# FiveLineColorsPlot111
a5 = 0.7
f5 = []
for num in x:
    f5.append(f(a5, num))
FiveLineColorsPlot111(x,f1,"f1",f2,"f2",f3,"f3",f4,"f4",f5,"f5","x","f(x)","FiveLineColorsPlot111","FiveLineColorsPlot111.png")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# <a id='linescatterplot'></a>
# ## Plotting a line and scatter plot together
# Below is an example of plotting a line plot and a scatter plot together. This is useful for plots where there is measured data and a curve fit or measured data and a theoretical curve for comparison. It is pretty easy to add to the *psm_plot.py* functions - if you need slightly different plots you can look at what I have written as examples.

# %%
# LineScatterPlot111
# make one plot as a line and one as scatter
LineScatterPlot111(x,f1,f2,"x","f(x)","LineScatterPlot111","LineScatterPlot111.png")

# %% [markdown]
# <a id='lineplotsub'></a>
# ## Sub Plots
# Below are examples of how to make multiple subplots in the same overall chart/object. Recall the many plots of position, velocity, and acceleration you made using the same time axis in physics... That would be one of many uses of subplots. Again, use these functions as a starting point and add to them as you need to.

# %%
# LinePlot211
# make two plots with same x
LinePlot211(x,f1,f2,"x","f1","f2","LinePlot211","LinePlot211.png")

# LinePlot121
# make two plots with same x
LinePlot121(x,f1,f2,"x","f1","f2","LinePlot121","LinePlot121.png")

# LinePlot311
# make three plots with same x
LinePlot311(x, f1, f2, f3, "x", "f1", "f2", "f3", "LinePlot311", "LinePlot311.png")

# LinePlot131
# make three plots with same x
LinePlot131(x, f1, f2, f3, "x", "f1", "f2", "f3", "LinePlot131", "LinePlot131.png")

# ScatterPlot211
# make two plots with same x
ScatterPlot211(x,f1,f2,"x","f1","f2","ScatterPlot211","ScatterPlot211.png")

# ScatterPlot121
# make two plots with same x
ScatterPlot121(x,f1,f2,"x","f1","f2","ScatterPlot121","ScatterPlot121.png")

# ScatterPlot311
# make three plots with same x
ScatterPlot311(x, f1, f2, f3, "x", "f1", "f2", "f3", "ScatterPlot311", "ScatterPlot311.png")

# ScatterPlot131
# make three plots with same x
ScatterPlot131(x, f1, f2, f3, "x", "f1", "f2", "f3", "ScatterPlot131", "ScatterPlot131.png")
